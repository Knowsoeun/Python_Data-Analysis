# %%
pip install pytrends
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pytrends.request import TrendReq

import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt

import folium

# %%
pytrends = TrendReq(hl='ko-KR', tz=360)

kw_list = ["테크", "2021 IT 트렌드", "IT 트렌드"]

pytrends.build_payload(kw_list, cat=0, timeframe='today 1-y', geo='', gprop='youtube')
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# <ipython-input-13-c2df10a0a667> in <module>
#       3 kw_list = ["테크", "2021 IT 트렌드", "IT 트렌드"]
#       4
# ----> 5 pytrends.build_payload(kw_list, cat=0, timeframe='today 1-y', geo='', gprop='youtube')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pytrends\request.py in build_payload(self, kw_list, cat, timeframe, geo, gprop)
#     167         self.token_payload['req'] = json.dumps(self.token_payload['req'])
#     168         # get tokens
# --> 169         self._tokens()
#     170         return
#     171
#
# C:\ProgramData\Anaconda3\lib\site-packages\pytrends\request.py in _tokens(self)
#     177             method=TrendReq.GET_METHOD,
#     178             params=self.token_payload,
# --> 179             trim_chars=4,
#     180         )['widgets']
#     181         # order of the json matters...
#
# ...

# %%
df_queries = pytrends.related_queries()

# %%
top_tech = df_queries.get("테크").get("top")
top_2021_IT = df_queries.get("2021 IT 트렌드").get("top")
top_IT_trend = df_queries.get("IT 트렌드").get("top")

df_top = pd.concat([top_tech, top_unboxing, top_IT_trend] )

df_top.sort_values(['value'], ascending = False).head(10).reset_index(drop = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-fef59608a397> in <module>
#       3 top_IT_trend = df_queries.get("IT 트렌드").get("top")
#       4
# ----> 5 df_top = pd.concat([top_tech, top_unboxing, top_IT_trend] )
#       6
#       7 df_top.sort_values(['value'], ascending = False).head(10).reset_index(drop = True)
#
# NameError: name 'top_unboxing' is not defined

# %%
rising_tech = df_queries.get("테크").get("rising")
rising_unboxing = df_queries.get("언박싱").get("rising")
rising_IT_trend = df_queries.get("IT 트랜드").get("rising")

df_rising = pd.concat([rising_tech, rising_unboxing, rising_IT_trend] )

df_rising.sort_values(['value'], ascending = False).head(10)
# Out:
#            query  value
# 0      테크 몽 성 이름  81350
# 1             5g  34850
# 2        테크 몽 논란  28700
# 0         z 플립 3  20350
# 3      항셍 테크 etf  17400
# 4             모카  11600
# 2       갤럭시 폴드 3    300
# 1  아이 패드 프로 5 세대    300
# 6     미국 테크 탑 10    250
# 4         아이폰 13    250

# %%
kw_list = ["5g", "z 플립 3", "항셍 테크 etf"]

pytrends.build_payload(kw_list, cat=0, timeframe='today 3-m', geo='', gprop='youtube')

df_interest = pytrends.interest_over_time().drop(columns='isPartial')

# %%
plt.figure(figsize=(16, 8))

plt.xticks(rotation=45)

sns.set(style="darkgrid", palette = 'rocket')

ax = sns.lineplot(data=df_interest)

ax.set_title('Tech Trends Over Time', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Tech Trends Over Time')
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 54540 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47549 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 54637 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49485 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 53580 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
